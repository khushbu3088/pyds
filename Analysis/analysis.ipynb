# %%
import pandas as pd

# %% [markdown]
# - how to create dataset in different ways
# - dictionary of items
# - list of items
# - importing csv files
# - importing excel files
# - importing json files
#
# - read dataframe
# - selection of data
# - manipulating the data
# - visualizing the data
# - loding the data

# %%
books={
    'title': ['Great Expectations','To kill a Mockingbird', 'Pride and prejudice','The Book Thief'],
    'aothor': ['Charles Dickens', 'Harper Lee','Jane Austen','Markus Zusak'],
    'published':[1861,1960,1813,2005],
    'price':[399,3567,1990,500]
    
}
pd.DataFrame(books)
# Out:
#                    title           aothor  published  price
# 0     Great Expectations  Charles Dickens       1861    399
# 1  To kill a Mockingbird       Harper Lee       1960   3567
# 2    Pride and prejudice      Jane Austen       1813   1990
# 3         The Book Thief     Markus Zusak       2005    500

# %%
movies=[{'title': 'stree','director':'Jony','length':129},
        {'title':'I','director':'horn'}
    
]
pd.DataFrame(movies)
# Out:
#    title director  length
# 0  stree     Jony   129.0
# 1      I     horn     NaN

# %%
url='https://raw.githubusercontent.com/digipodium/Datasets/main/regression/kc_house_data.csv'
df=pd.read_csv(url)

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.sample()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 11527  2877102180  20140829T000000  505000.0         2        1.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 11527         1020      5000     1.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 11527        1020              0      1916             0    98117  47.6781
#
#           long  sqft_living15  sqft_lot15
# 11527 -122.363           1480        5000
#
# [1 rows x 21 columns]

# %%
df.sample(3)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 17721   472000590  20140624T000000   845000.0         3       2.00
# 4655   2391601380  20150223T000000   390000.0         3       2.25
# 3813   1118000301  20141219T000000  2890000.0         4       4.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 17721         2540      4750     1.5           0     0  ...      9
# 4655          1650      6250     1.5           0     0  ...      7
# 3813          5780      7173     2.0           0     0  ...     11
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 17721        1840            700      1930             0    98117  47.6838
# 4655         1650              0      1910             0    98116  47.5639
# 3813         4130           1650      2008             0    98112  47.6374
#
#           long  sqft_living15  sqft_lot15
# 17721 -122.400           2190        4750
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.describe(include='object')
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %% [markdown]
# - selecting data in pandas
#  - row wise
#   - iloc-index based location
#   - loc-label based location
# - column wise
#  - single column selection
#  - multiple column selection

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.iloc[3]
# Out:
# id                    2487200875
# date             20141209T000000
# price                   604000.0
# bedrooms                       4
# bathrooms                    3.0
# sqft_living                 1960
# sqft_lot                    5000
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      5
# grade                          7
# sqft_above                  1050
# sqft_basement                910
# yr_built                    1965
# yr_renovated                   0
# zipcode                    98136
# lat                      47.5208
# long                    -122.393
# sqft_living15               1360
# sqft_lot15                  5000
# Name: 3, dtype: object

# %%
df.iloc[[1,59,100,300]]
# Out:
#              id             date      price  bedrooms  bathrooms  sqft_living  \
# 1    6414100192  20141209T000000   538000.0         3       2.25         2570
# 59   8079040320  20150223T000000   430000.0         4       3.00         1850
# 100  1952200240  20140611T000000   850830.0         3       2.50         2070
# 300  3225069065  20140624T000000  3075000.0         4       5.00         4550
#
#      sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1        7242     2.0           0     0  ...      7        2170
# 59       9976     2.0           0     0  ...      8        1850
# 100     13241     1.5           0     0  ...      9        1270
# 300     18641     1.0           1     4  ...     10        2600
#
#      sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1              400      1951          1991    98125  47.7210 -122.319
# 59               0      1991             0    98059  47.5059 -122.149
# ...

# %%
df.iloc[[1,10,20],[0,1,4,6]]
# Out:
#             id             date  bathrooms  sqft_lot
# 1   6414100192  20141209T000000       2.25      7242
# 10  1736800520  20150403T000000       2.50      9796
# 20  6300500875  20140514T000000       1.75      4980

# %%
df.iloc[15:25,:10]
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 15  9297300055  20150124T000000   650000.0         4       3.00         2950
# 16  1875500060  20140731T000000   395000.0         3       2.00         1890
# 17  6865200140  20140529T000000   485000.0         4       1.00         1600
# 18    16000397  20141205T000000   189000.0         2       1.00         1200
# 19  7983200060  20150424T000000   230000.0         3       1.00         1250
# 20  6300500875  20140514T000000   385000.0         4       1.75         1620
# 21  2524049179  20140826T000000  2000000.0         3       2.75         3050
# 22  7137970340  20140703T000000   285000.0         5       2.50         2270
# 23  8091400200  20140516T000000   252700.0         2       1.50         1070
# 24  3814700200  20141120T000000   329000.0         3       2.25         2450
#
#     sqft_lot  floors  waterfront  view
# 15      5000     2.0           0     3
# 16     14040     2.0           0     0
# ...

# %%
df=df.set_index('id')
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
# ...

# %%
df.loc[7129300520]
# Out:
# date             20141013T000000
# price                   221900.0
# bedrooms                       3
# bathrooms                    1.0
# sqft_living                 1180
# sqft_lot                    5650
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1180
# sqft_basement                  0
# yr_built                    1955
# yr_renovated                   0
# zipcode                    98178
# lat                      47.5112
# long                    -122.257
# sqft_living15               1340
# sqft_lot15                  5650
# Name: 7129300520, dtype: object

# %%
df.loc[[7129300520,2487200875]]
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3        1.0         1180
# 2487200875  20141209T000000  604000.0         4        3.0         1960
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 2487200875      5000     1.0           0     0          5      7        1050
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 7129300520              0      1955             0    98178  47.5112 -122.257
# 2487200875            910      1965             0    98136  47.5208 -122.393
#
#             sqft_living15  sqft_lot15
# id
# 7129300520           1340        5650
# 2487200875           1360        5000

# %% [markdown]
# Single column Selection
# - dictionary like selection
# - dataframe ['column_name]
# - object like selection
#   - dataframe.column_name
#
# Multiple column selection
# - dictionary like selection
#   - dataframe['list_of_column_names']

# %%
df['price']
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df.bedrooms
# Out:
# id
# 7129300520    3
# 6414100192    3
# 5631500400    2
# 2487200875    4
# 1954400510    3
#              ..
# 263000018     3
# 6600060120    4
# 1523300141    2
# 291310100     3
# 1523300157    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
df[['price','bedrooms','bathrooms']]
# Out:
#                price  bedrooms  bathrooms
# id
# 7129300520  221900.0         3       1.00
# 6414100192  538000.0         3       2.25
# 5631500400  180000.0         2       1.00
# 2487200875  604000.0         4       3.00
# 1954400510  510000.0         3       2.00
# ...              ...       ...        ...
# 263000018   360000.0         3       2.50
# 6600060120  400000.0         4       2.50
# 1523300141  402101.0         2       0.75
# 291310100   400000.0         3       2.50
# 1523300157  325000.0         2       0.75
#
# [21613 rows x 3 columns]

# %% [markdown]
# Manipulating and Cleaning Data
# - removing rows and columns
# - rename column names
# - adding columns
# - changing datatypes
# - handling missing values
# - dropping missing values
# - using apply() methods

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#removing rows
df.drop(7129300520)
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 6414100192  20141209T000000   538000.0         3       2.25         2570
# 5631500400  20150225T000000   180000.0         2       1.00          770
# 2487200875  20141209T000000   604000.0         4       3.00         1960
# 1954400510  20150218T000000   510000.0         3       2.00         1680
# 7237550310  20140512T000000  1225000.0         4       4.50         5420
# ...                     ...        ...       ...        ...          ...
# 263000018   20140521T000000   360000.0         3       2.50         1530
# 6600060120  20150223T000000   400000.0         4       2.50         2310
# 1523300141  20140623T000000   402101.0         2       0.75         1020
# 291310100   20150116T000000   400000.0         3       2.50         1600
# 1523300157  20141015T000000   325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df
# Out:
#                        date     price  bedrooms  bathrooms  floors  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00     1.0
# 6414100192  20141209T000000  538000.0         3       2.25     2.0
# 5631500400  20150225T000000  180000.0         2       1.00     1.0
# 2487200875  20141209T000000  604000.0         4       3.00     1.0
# 1954400510  20150218T000000  510000.0         3       2.00     1.0
# ...                     ...       ...       ...        ...     ...
# 263000018   20140521T000000  360000.0         3       2.50     3.0
# 6600060120  20150223T000000  400000.0         4       2.50     2.0
# 1523300141  20140623T000000  402101.0         2       0.75     2.0
# 291310100   20150116T000000  400000.0         3       2.50     2.0
# 1523300157  20141015T000000  325000.0         2       0.75     2.0
#
#             waterfront  view  condition  grade  sqft_above  sqft_basement  \
# id
# 7129300520           0     0          3      7        1180              0
# ...

# %%
cols_to_drop=['sqft_lot','sqft_living']
df.drop(columns=cols_to_drop)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 2
#       1 cols_to_drop=['sqft_lot','sqft_living']
# ----> 2 df.drop(columns=cols_to_drop)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df.drop(labels=[7129300520,2487200875])
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 6414100192  20141209T000000   538000.0         3       2.25         2570
# 5631500400  20150225T000000   180000.0         2       1.00          770
# 1954400510  20150218T000000   510000.0         3       2.00         1680
# 7237550310  20140512T000000  1225000.0         4       4.50         5420
# 1321400060  20140627T000000   257500.0         3       2.25         1715
# ...                     ...        ...       ...        ...          ...
# 263000018   20140521T000000   360000.0         3       2.50         1530
# 6600060120  20150223T000000   400000.0         4       2.50         2310
# 1523300141  20140623T000000   402101.0         2       0.75         1020
# 291310100   20150116T000000   400000.0         3       2.50         1600
# 1523300157  20141015T000000   325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...
