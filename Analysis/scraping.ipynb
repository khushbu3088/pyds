# %% [markdown]
# - pip install dputils

# %%
from dputils.scrape import Scraper,Tag
from pprint import pp

# %% [markdown]
# - Tag class hepls to decide what to collect from the page
# - Scraper executes the scraping process

# %%
url='https://www.amazon.in/s?k=mobile%27&adgrpid=1317216539842212&hvadid=82326291885454&hvbmt=be&hvdev=c&hvlocphy=149639&hvnetw=o&hvqmt=e&hvtargid=kwd-82326917120801%3Aloc-90&hydadcr=15398_1978084&tag=msndeskstdin-21&ref=pd_sl_8krcvc30ps_e'
